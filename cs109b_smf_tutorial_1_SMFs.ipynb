# %% [markdown]
# ## Harvard CS109b
# ### Tutorial (1)
# ### Pan-STARRS SMF Data Format
# ### Matthew J. Holman, Matthew J. Payne
# #### 22 April 2019

# %%
import numpy as np
import pandas as pd
import scipy.interpolate as interpolate
pd.set_option('display.max_rows', 999)
pd.set_option('display.width', 500)
pd.set_option('display.notebook_repr_html', True)
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math
import random
import itertools
from collections import defaultdict
import importlib
from astropy.io import fits

import ps1_astrom
import ps1_utils

from scipy.optimize import curve_fit
import scipy as sp

import ephem
import healpy as hp

import os
from scipy import spatial
import sqlite3 as lite
import sys
import warnings

from collections import Counter

import socket

import warnings
warnings.filterwarnings('ignore')

# Make the figures bigger
plt.rcParams['figure.figsize'] = [13, 13]

# %%
first=lambda x: x[0]
second=lambda x: x[1]

# %% [markdown]
# ### The Pan-STARRS-1 Data
#
# Rather than searching the Pan-STARRS-1 images themselves, we rely on catalogs of detections extracted from those images by the Image Processing Pipeline (IPP) [reference needed].  The image data comprises petabytes.  Fortunately, the catalogs extracted from those images comprise terabytes.
#
# We have access to 1.3 million smf files. And more are being generated all the time (now on PS1 and PS2).
#
# The Pan-STARRS catalog data from each exposure is stored in a multi-extension FITS files called an 'smf file', so named from its suffix.  I have no idea what 'smf' stands for or if 'file' is redundant, as in 'S M File file'.
#
# There are 182 extensions in a standard smf.  These are:
#
# + PRIMARY for the overall exposure.  This includes the filter, the time and duration of the exposure, WCS information, and much, much more.  There is only header information for PRIMARY
#
# + MATCHED_REFS contains information about the referencd stars that were used to determine the astrometric solution and photometric zero point for the overall exposure as well as for each detector.  MATCHED_REFS has both header information and data.  The data is a binary table of the stars used.  It's incredibly useful!
#
# + For each of the 60 detectors/chips there is an '.hdr' extension, a '.psf' extension, and a '.deteff' extension.
#
#     - The '.hdr' extension contains header information for that detector.   This includes WCS information, and much much more.
#
#     - The '.psf' extension is a binary table with each row representing a detection returned by the IPP.
#
#     - The '.deteff' extension contains detection efficiency results based on synthetic sources inserted into the detector by the IPP.
#
#
#
# Let's explore the structure and content of an smf file.  The fits package in astropy.io makes this very easy.
#
# We can open any FITS file as below.  We get back an collection of HDU (Header-Data Units).
#
# It takes about a second to open an smf file.  We can iterate over the HDUs in various pythonic ways.  (Refer to the astropy documentation for more details.)

# %% [markdown]
# We will use the FITS library in astropy for much of this work:
#
# http://docs.astropy.org/en/stable/io/fits/index.html

# %%
from astropy.io import fits

# %% [markdown]
# Here we use the fits library to open an example smf file named 'o6771g0234o.729155.cm.943415.smf'

# %%
# %%time
smf = 'smf/o6771g0234o.729155.cm.943415.smf'

hdus = fits.open(smf)
# Out:
# CPU times: user 904 ms, sys: 31.8 ms, total: 936 ms
# Wall time: 961 ms

# %% [markdown]
# Here we will show how to plot the detections for a particular 'chip' within the smf file (we discuss the structure of the detections & the smf files in greater detail below)

# %%
_=plt.scatter(hdus['XY13.psf'].data['RA_PSF'], hdus['XY13.psf'].data['DEC_PSF'], s=3)

# %% [markdown]
#  It's handy to have a list of the names of the chips.  They are organized into an x-y grid, with the corners missing.

# %%
chips=['XY01', 'XY02', 'XY03', 'XY04', 'XY05', 'XY06',
       'XY10', 'XY11', 'XY12', 'XY13', 'XY14', 'XY15', 'XY16', 'XY17',
       'XY20', 'XY21', 'XY22', 'XY23', 'XY24', 'XY25', 'XY26', 'XY27',
       'XY30', 'XY31', 'XY32', 'XY33', 'XY34', 'XY35', 'XY36', 'XY37',
       'XY40', 'XY41', 'XY42', 'XY43', 'XY44', 'XY45', 'XY46', 'XY47',
       'XY50', 'XY51', 'XY52', 'XY53', 'XY54', 'XY55', 'XY56', 'XY57',
       'XY60', 'XY61', 'XY62', 'XY63', 'XY64', 'XY65', 'XY66', 'XY67',
       'XY71', 'XY72', 'XY73', 'XY74', 'XY75', 'XY76']

# %% [markdown]
# We can now plot the data from all of the detectors.
# The detectors are the large squares of detections in the plot below, with each detector having a coherent color.
# There are gaps between the large square detectors.
# Each detector is composed of an 8x8 grid of 'cells.'
# There is an insensitve region separating each cell from its neighbors.  In addition, some cells are 'dead.'  There are no detections reported by dead cells.
#
# There appears to be an excess points along the edges of the cells.
# This shows up as a 'waffle pattern' in the image below.  These excess points are very likely to be false detections.

# %%
for chip in chips:
    extension_name = chip+'.psf'
    hdu = hdus[extension_name]
    _=plt.scatter(hdu.data['RA_PSF'], hdu.data['DEC_PSF'], s=1)

# %% [markdown]
# We see all 182 extension names.

# %%
hdu_names = [hdu.name for hdu in hdus]
hdu_names
# Out:
# ['PRIMARY',
#  'MATCHED_REFS',
#  'XY01.hdr',
#  'XY01.psf',
#  'XY01.deteff',
#  'XY02.hdr',
#  'XY02.psf',
#  'XY02.deteff',
#  'XY03.hdr',
#  'XY03.psf',
#  'XY03.deteff',
#  'XY04.hdr',
#  'XY04.psf',
#  'XY04.deteff',
#  'XY05.hdr',
#  'XY05.psf',
#  'XY05.deteff',
#  'XY06.hdr',
#  'XY06.psf',
#  'XY06.deteff',
#  'XY10.hdr',
#  'XY10.psf',
#  'XY10.deteff',
#  'XY11.hdr',
#  'XY11.psf',
#  'XY11.deteff',
#  'XY12.hdr',
#  'XY12.psf',
#  'XY12.deteff',
#  'XY13.hdr',
#  'XY13.psf',
#  'XY13.deteff',
#  'XY14.hdr',
#  'XY14.psf',
#  'XY14.deteff',
#  'XY15.hdr',
#  'XY15.psf',
#  'XY15.deteff',
#  'XY16.hdr',
#  'XY16.psf',
#  'XY16.deteff',
#  'XY17.hdr',
#  'XY17.psf',
#  'XY17.deteff',
#  'XY20.hdr',
#  'XY20.psf',
#  'XY20.deteff',
#  'XY21.hdr',
#  'XY21.psf',
#  'XY21.deteff',
#  'XY22.hdr',
#  'XY22.psf',
#  'XY22.deteff',
#  'XY23.hdr',
#  'XY23.psf',
#  'XY23.deteff',
#  'XY24.hdr',
#  'XY24.psf',
#  'XY24.deteff',
#  'XY25.hdr',
#  'XY25.psf',
#  'XY25.deteff',
#  'XY26.hdr',
#  'XY26.psf',
#  'XY26.deteff',
#  'XY27.hdr',
#  'XY27.psf',
#  'XY27.deteff',
#  'XY30.hdr',
#  'XY30.psf',
#  'XY30.deteff',
#  'XY31.hdr',
#  'XY31.psf',
#  'XY31.deteff',
#  'XY32.hdr',
#  'XY32.psf',
#  'XY32.deteff',
#  'XY33.hdr',
#  'XY33.psf',
#  'XY33.deteff',
#  'XY34.hdr',
#  'XY34.psf',
#  'XY34.deteff',
#  'XY35.hdr',
#  'XY35.psf',
#  'XY35.deteff',
#  'XY36.hdr',
#  'XY36.psf',
#  'XY36.deteff',
#  'XY37.hdr',
#  'XY37.psf',
#  'XY37.deteff',
#  'XY40.hdr',
#  'XY40.psf',
#  'XY40.deteff',
#  'XY41.hdr',
#  'XY41.psf',
#  'XY41.deteff',
#  'XY42.hdr',
#  'XY42.psf',
#  'XY42.deteff',
#  'XY43.hdr',
#  'XY43.psf',
#  'XY43.deteff',
#  'XY44.hdr',
#  'XY44.psf',
#  'XY44.deteff',
#  'XY45.hdr',
#  'XY45.psf',
#  'XY45.deteff',
#  'XY46.hdr',
#  'XY46.psf',
#  'XY46.deteff',
#  'XY47.hdr',
#  'XY47.psf',
#  'XY47.deteff',
#  'XY50.hdr',
#  'XY50.psf',
#  'XY50.deteff',
#  'XY51.hdr',
#  'XY51.psf',
#  'XY51.deteff',
#  'XY52.hdr',
#  'XY52.psf',
#  'XY52.deteff',
#  'XY53.hdr',
#  'XY53.psf',
#  'XY53.deteff',
#  'XY54.hdr',
#  'XY54.psf',
#  'XY54.deteff',
#  'XY55.hdr',
#  'XY55.psf',
#  'XY55.deteff',
#  'XY56.hdr',
#  'XY56.psf',
#  'XY56.deteff',
#  'XY57.hdr',
#  'XY57.psf',
#  'XY57.deteff',
#  'XY60.hdr',
#  'XY60.psf',
#  'XY60.deteff',
#  'XY61.hdr',
#  'XY61.psf',
#  'XY61.deteff',
#  'XY62.hdr',
#  'XY62.psf',
#  'XY62.deteff',
#  'XY63.hdr',
#  'XY63.psf',
#  'XY63.deteff',
#  'XY64.hdr',
#  'XY64.psf',
#  'XY64.deteff',
#  'XY65.hdr',
#  'XY65.psf',
#  'XY65.deteff',
#  'XY66.hdr',
#  'XY66.psf',
#  'XY66.deteff',
#  'XY67.hdr',
#  'XY67.psf',
#  'XY67.deteff',
#  'XY71.hdr',
#  'XY71.psf',
#  'XY71.deteff',
#  'XY72.hdr',
#  'XY72.psf',
#  'XY72.deteff',
#  'XY73.hdr',
#  'XY73.psf',
#  'XY73.deteff',
#  'XY74.hdr',
#  'XY74.psf',
#  'XY74.deteff',
#  'XY75.hdr',
#  'XY75.psf',
#  'XY75.deteff',
#  'XY76.hdr',
#  'XY76.psf',
#  'XY76.deteff']

# %% [markdown]
#  The PRIMARY contains a wealth of information about the overall mosaic of detectors, such as when the exposure was taken, what filter was used, where the telescope was pointing, and how long the exposure was.

# %%
hdus['PRIMARY'].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / this file has extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CONTROLR= 'STARGRASP'
# PSFORMAT= 'MEF     '
# PSMOSAIC= 'CHIP    '           / Mosaicked level
# M2Z     =             -1179.55 / Telescope focus
# FILTERID= 'w.00000 '           / Filter used (instrument name)
# POSANGLE=             275.7954 / Position angle of instrument
# ROT     =            -137.7034 / Rotator angle of instrument
# EQUINOX = '2000.000000'        / Celestial coordinate system
# RA      =           209.539028 / Right Ascension of boresight
# DEC     =            -7.239602 / Declination of boresight
# OBSTYPE = 'OBJECT  '           / Type of observation
# OBJECT  = 'ps1_14_3759'        / Object of observation
# ALT     =            51.166152 / Altitude of boresight
# AZ      =           134.802918 / Azimuth of boresight
# DETTEM  =                -75.6 / Temperature of focal plane
# EXPREQ  =                  45. / Exposure time (sec)
# MAG_ZP  =             25.89705 / Magnitude zero point
# MJD-OBS =     56771.3535100743 / Time of observation
# EXPTIME =                  45. / Exposure time (sec)
# AIRMASS =                1.274 / Observation airmass
# IMNAXIS1=                40023 / Mosaic Dimensions
# IMNAXIS2=                41303 / Mosaic Dimensions
# CTYPE1  = 'RA---DIS'
# CTYPE2  = 'DEC--DIS'
# CRVAL1  =     209.539026420806
# CRVAL2  =    -7.23960117580802
# CRPIX1  =    -4.67375305660753
# CRPIX2  =     2.48246710762536
# CDELT1  = 7.07942378738816E-05
# CDELT2  = 7.07920498716352E-05
# PC001001=     -0.1008630543326
# PC001002=    0.994931068599928
# PC002001=   -0.994850019123996
# PC002002=    -0.10105572047663
# PCA1X0Y2= 5.17819787341499E-06
# PCA2X0Y2= -3.67481093660112E-05
# PCA1X0Y3= -0.00177823985718933
# PCA2X0Y3= 0.000146992576900279
# PCA1X1Y1= 1.64578411927998E-05
# PCA2X1Y1= -8.10371073612274E-08
# PCA1X1Y2= 0.000243297574288909
# PCA2X1Y2=  0.00143854401010175
# PCA1X2Y0= -3.16980762741752E-05
# PCA2X2Y0= -9.72772006799481E-05
# PCA1X2Y1= -0.00165236652001664
# PCA2X2Y1= 0.000142540937773889
# PCA1X3Y0= 0.000177379775826868
# PCA2X3Y0=  0.00174011703914007
# NPLYTERM=                    3
# DT_ASTR =             21.03811 / elapsed psastro time
# ZPT_OBS =             25.89705 / measured zero point
# ZPT_REF =                 26.3 / reference zero point
# ZPT_ERR =             0.048666 / error on zero point
# ZPT_OFF =            0.4029503 / zero point offset
# AST_R0  =            -6.760468 / boresite offset in RA (TP units)
# AST_D0  =             19.37841 / boresite offset in DEC (TP units)
# AST_T0  =           0.09678154 / boresite angle (degrees)
# AST_S0  =             1.000483 / boresite scale correction
# AST_RS  =             7.214127 / boresite scatter in RA (TP units)
# AST_DS  =             5.112679 / boresite scatter in DEC (TP units)
# NGHOSTS =                48795 / total expected ghosts

# %% [markdown]
# Each detector also has a header of information that is specific to it.

# %%
hdus['XY13.hdr'].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# EXTEND  =                    T / File contains extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# NEXTEND =                   64 / Number of extensions
# QUEUEID = '176.OSS.R13S1.Q.w'
# TESSEL  =                -9999
# FILENAME= 'o6771g0234o13'      / Base filename at acquisition
# DATE    = '2014-04-24T08:29:16' / UTC Date of file creation
# IMGSWPRG= 'grasp_save_ota v1.35 SVN 4362 (Nov 10 2010)' / Image creation softwar
# IMAGESWV= '4362    '           / Image creation software version
# ORIGIN  = 'PS1     '           / IfA Pan-STARRS 1
# INSTRUME= 'gpc1    '           / Instrument Name
# FPPOS   = 'xy13    '           / Position of detector in focal plane mosaic
# SATTIME =                34703 / [sec] Time since last detected saturation event
# TRKTIME =               185331 / [sec] Time since last detected tracking error
# VDOTIME =               349062 / [sec] Time since "video" command used
# COMMENT Detector
# COMMENT --------
# NAMPS   =                   64 / Number of amplifiers in the detector
# DETPKGID=                  205 / Detector package ID
# COMMENT If DETTEMOV is T, DETTEMP was overridden. Old
# COMMENT temp. is CDETTEM and new temp. was derived as:
# COMMENT V = (ADU-B) / (A*32768)
# COMMENT T = 3369-sqrt[3369^2+1313^2*(13.1*V-1)/(V-1)]
# DETTEMOV=                    T / Detector temperature overridden
# DETTEADU=                 1727 / [ADU] Detector temperature A/D measurement
# DETTCOFA=                1.122 / Coefficient A used in overriding detector temp.
# DETTCOFB=                 -243 / Coefficient B used in overriding detector temp.
# PIXSIZE1=                  10. / [um] Pixel size for axis 1
# PIXSIZE2=                  10. / [um] Pixel size for axis 2
# COMMENT xy(0,7) S S S S S S S S  ------------------------------------------
# COMMENT xy(0,6) S S S S S S S D  Cell usage for EXTNAME='xy__'
# COMMENT xy(0,5) S S S S S S S S
# COMMENT xy(0,4) S S S S S S S S     Legend:
# COMMENT xy(0,3) S S S S S S S S      (S) Science data from cell
# COMMENT xy(0,2) S S S S S S S S      (V) Video data from cell
# COMMENT xy(0,1) S S S S S S S S      (F) Floated cell (no data)
# COMMENT xy(0,0) S S S D S S S S      (D) Dead cell (no data)
# COMMENT         0 1 2 3 4 5 6 7  ------------------------------------------
# IMTM1_1 =                  -1. / IMage Transform Matrix; A unit vector in the
# IMTM1_2 =                   0. /  serial (fast) direction of amplifier readout
# IMTM2_1 =                   0. / And a unit vector in parallel (slow) direction
# IMTM2_2 =                   1. /  of amplifier readout
# CELLGAP1=                   18 / Cell gap between columns (in unbinned pixels)
# CELLGAP2=                   12 / Cell gap between rows (in unbinned pixels)
# CNAXIS1 =                  590 / Cell imaging size in unbinned pixel columns
# CNAXIS2 =                  598 / Cell imaging size in unbinned pixel rows
# CNPIX1  =                    0 / Offset in unbinned pixel cols to readout start
# CNPIX2  =                    0 / Offset in unbinned pixel rows to readout start
# CCDBIN1 =                    1 / Binning factor along axis 1
# CCDBIN2 =                    1 / Binning factor along axis 2
# PRESCAN1=                    0 / Prescan count on axis 1
# PRESCAN2=                    0 / Prescan count on axis 2
# OVRSCAN1=                   34 / Overscan count on axis 1
# OVRSCAN2=                   10 / Overscan count on axis 2
# COMMENT   Iraf coordinates
# COMMENT   ----------------
# DETSIZE = '[1:4846,1:4868]'    / Iraf total image pixels in full mosaic
# COMMENT   Controller Data
# COMMENT   ---------------
# CONTROLR= 'STARGRASP'          / Detector Controller
# CONSWURL= 'https://svn/gpc/repos/sw/branches/u-boot-gpc1' / Controller software
# CONSWV  = '4928    '           / Controller software SVN revision
# CON_MAC = '00:50:c2:64:90:36'  / Controller MAC (HW Ethernet) Address
# CON_IP  = '192.168.0.187'      / Controller IP Address
# CON_NAME= 'gpc1B1  '           / Controller IP Hostname
# CON_DEV =                    0 / Controller device number (0 or 1)
# CON_UP  =              6172290 / [seconds] Controller up-time
# CON_VSUM= 'dca9b32498036f6b0a68e94ea28d52b3' / Device operating point md5sum
# TSP_SHOP=                    0 / Milliseconds from last clean to shutter open
# TSP_SHCL=                    0 / Milliseconds from last clean to shutter close
# TSP_RD00=                49772 / Milliseconds darktime for buffer (cell row) 0
# TSP_RD01=                50621 / Milliseconds darktime for buffer (cell row) 1
# TSP_RD02=                51470 / Milliseconds darktime for buffer (cell row) 2
# TSP_RD03=                52320 / Milliseconds darktime for buffer (cell row) 3
# TSP_RD04=                53169 / Milliseconds darktime for buffer (cell row) 4
# TSP_RD05=                54018 / Milliseconds darktime for buffer (cell row) 5
# TSP_RD06=                54867 / Milliseconds darktime for buffer (cell row) 6
# TSP_RD07=                55717 / Milliseconds darktime for buffer (cell row) 7
# TSP_NOW =                50694 / Milliseconds from last clean until save
# CLV_PPG4= 'ecbb:cbb2:bb2e:65d8:5d97:38ba:6622:3154' / Coded parallel timings
# CLV_PG3 = '340e:40e0:1c03:c070:06c1:0417:649b:0136' / Coded serial timings
# CLV_PG4 = '1038:8010:0104:00b0:07c2:0000:3732:08a2' / Coded SW/RST/VCLAMP/SAMP
# CLV_ADC = '1500:7  '           / Coded ADC parameters
# CLV_MATH= '333301111A'         / Coded Math Engine multi-sample processing
# CLV_MCAL= '1111A1111A'         / Coded Math Engine for 32bpp out (readcal)
# CLV_TRIG=                   10 / Cross-trigger phase delay (x 10nsec)
# CLV_PRES=                    3 / Serial prescan, (skipped in addition to CNPIX1)
# CLV_PIPE=                    1 / Clocking pattern pipeline (in addition to ADC)
# CLV_PXTP=                    1 / OT Pixel Type 1 or 2 (or 0 for normal CCD)
# ADC_CONF= '0c8:0c8:0c8:0c8:0c8:0c8:0c8:0c8' / ADC configuration
# ADC_MUX = '0c0:0c0:0c0:0c0:0c0:0c0:0c0:0c0' / ADC MUX configuration
# ADC_PGAR= '019:019:019:019:019:019:019:019' / Red ADC pga (adcgain 1.5)
# ADC_PGAG= '000:000:000:000:000:000:000:000' / Grn ADC pga (adcgain val)
# ADC_PGAB= '000:000:000:000:000:000:000:000' / Blu ADC pga (adcgain val)
# ADC_OFSR= '000:000:000:000:000:000:000:000' / Red ADC offset
# ADC_OFSG= '000:000:000:000:000:000:000:000' / Grn ADC offset
# ADC_OFSB= '000:000:000:000:000:000:000:000' / Blu ADC offset
# DAC_INIT=                 1600 / [mV] DAC internal vref offset voltage
# DAC_S_L =                  -1. / [V] Serial and summing well LO dac06=-1000 mV
# DAC_S_H =                   7. / [V] Serial and summing well HI dac07=+7000 mV
# DAC_P_L =                   1. / [V] Parallel and P. standby LO dac14=+1000 mV
# DAC_P_H =                  8.5 / [V] Parallel and P. standby HI dac15=+8500 mV
# DAC_RG_L=                  -2. / [V] Reset Gate LO              dac16=-2000 mV
# DAC_RG_H=                  10. / [V] Reset Gate HI              dac17=+10000 mV
# DAC_SO  =                  4.1 / [V] 1st Stage Source           dac18=+4100 mV
# DAC_DR  =                 19.5 / [V] Drain Bias                 dac19=+6500 mV
# DAC_VSS =                 -0.5 / [V] Logic Low Supply           dac20=-0500 mV
# DAC_VDDL=                   6. / [V] Logic Drain Supply LO      dac21=+6000 mV
# DAC_VDDH=                  15. / [V] Logic Drain Supply HI      dac22=+7500 mV
# DAC_OG1 =                  0.5 / [V] Output Gate Bias           dac25=+0500 mV
# DAC_RD  =                 12.2 / [V] Reset Drain Bias           dac26=+6100 mV
# DAC_SUB =               -7.005 / [V] Substrate                  dac27=-2335 mV
# DAC_SCP =                  20. / [V] Scupper Bias               dac28=+10000 mV
# DAC_LREF=                  -1. / [V] Logic Reference Ground     dac29=-1000 mV
# DAC_CAL0= '-418 -401 -424 -399 -124 -438 -395 -383' / [mV] Pedestal cal
# DAC_CAL1= '-413 -376 -409 -367 -404 -393 -354 -354' / [mV] Pedestal cal
# DAC_CAL2= '-408 -374 -396 -350 -393 -388 -336 -347' / [mV] Pedestal cal
# DAC_CAL3= '-385 -352 -379 -332 -367 -370 -331 -337' / [mV] Pedestal cal
# DAC_CAL4= '-361 -336 -364 -315 -350 -355 -322 -332' / [mV] Pedestal cal
# DAC_CAL5= '-351 -310 -346 -298 -344 -338 -316 -322' / [mV] Pedestal cal
# DAC_CAL6= '-124 -302 -335 -286 -330 -326 -299 -315' / [mV] Pedestal cal
# DAC_CAL7= '-317 -281 -315 -272 -317 -313 -292 -297' / [mV] Pedestal cal
# COMMENT Shutter
# COMMENT -------
# SHUTSTAT= 'OK      '           / Shutter status
# SHUTERR = '        '           / Shutter error code
# SHUTOPEN= '2014-04-24 08:29:03.270413' / [TAI date time] Shutter open time
# SHUTCLOS= '2014-04-24 08:29:48.270416' / [TAI date time] Shutter close time
# SHUTOPWN=              3.0E-06 / [sec] Shutter open uncertainty before SHUTOPEN
# SHUTCLWN=              3.0E-06 / [sec] Shutter close uncertainty before SHUTCLOS
# SHUTCUTC= '2014-04-24 08:29:13.270416' / [UTC date time] Shutter close time
# SHUTLEAP=                   35 / [sec] Leap seconds used in TAI-UTC conversion
# SHUTREQ =                  45. / [sec] Requested exposure duration
# SHUTTIME=            45.000003 / [sec] Actual exposure duration
# SHUTOPBL= 'A       '           / Shutter blade in aperture at start of exposure
# SHUTCLBL= 'B       '           / Shutter blade in aperture at end of exposure
# SHUTDAVR= '1.33    '           / Shutter daemon version
# SHUTDRVR= '1.15    '           / Shutter driver version
# COMMENT Telescope and Pointing Information
# COMMENT ----------------------------------
# TELESCOP= 'PS1     '           / IfA Pan-STARRS 1
# TELSTAT = 'GUIDING '           / Telescope control system status
# DOMSTAT = 'FULL OPEN'          / Telescope enclosure status
# RASTRNG = '209:32:20.500'      / [deg:mm:ss] Telescope sexagesimal Right Ascen.
# DECSTRNG= '-7:14:22.566'       / [deg:mm:ss] Telescope sexagesimal Declination
# AZALTTIM=       1398328106.717 / [s] Unix time corresponding to AZ,ALT,ROT
# COMRA   =              209.539 / [deg] Commanded telescope Right Ascension
# COMDEC  =              -7.2396 / [deg] Commanded telescope Declination
# COMAZ   =           134.266473 / [deg] Commanded telescope azimuth
# COMALT  =            51.693966 / [deg] Commanded telescope pointing altitude
# COMROT  =          -137.703213 / [deg] Commanded telescope rotator angle
# MOONANG =           120.492113 / [deg] Angular distance to moon
# COMMENT NOTE: Telescope RA DEC or ALT AZ already include
# COMMENT       the following offsets.  Do not re-apply!
# TELOFRA =                   0. / [deg] Telescope offset in RA
# TELOFDEC=                   0. / [deg] Telescope offset in DEC
# TELOFAZ =                   0. / [deg] Telescope offset in AZ
# TELOFALT=                   0. / [deg] Telescope offset in ALT
# TELOFROT=                   0. / [deg] Telescope offset in ROT
# TELOFX  =                   0. / [deg] Telescope offset in camera X
# TELOFY  =                   0. / [deg] Telescope offset in camera Y
# GUISTAT = 'OK      '           / Telescope guiding system status
# GUICONF = 'GUIDING '           / Telescope guiding configuration
# GUISTAR = 'multi-star'         / Telescope guiding (single or multi-star)
# GUIROTEN=                    F / Telescope guiding rotation enabled
# GUIGAIX =                 0.25 / Telescope guiding gain factor (x offset)
# GUIGAIY =                 0.25 / Telescope guiding gain factor (y offset)
# GUIRATE =                   1. / [Hz] Telescope guiding rate
# GUIKERN = '0,0,0,0,0,1,2,3,2,1' / Filter kernel used for guiding
# GUIKLEN =                   10 / Number of taps in filter kernel
# GUIKSUM =                    9 / Sum of all filter kernel taps
# GUINSTAR=                -9999 / Number of guide stars unavailable
# GUINOK  =                -9999 / Number of guide stars unavailable
# GUIERR  =                -9999 / Guide fit error codes unavailable
# GUIDR   =             -9999.99 / Guide star offset RMS unavailable
# GUIXMED =             -9999.99 / Guide star x offsets unavailable
# GUIX50  =             -9999.99 / Guide star x offsets unavailable
# GUIX90  =             -9999.99 / Guide star x offsets unavailable
# GUIYMED =             -9999.99 / Guide star y offsets unavailable
# GUIY50  =             -9999.99 / Guide star y offsets unavailable
# GUIY90  =             -9999.99 / Guide star y offsets unavailable
# GUIROT  =             -9999.99 / Guide star rotation offsets unavailable
# GUIROT90=             -9999.99 / Guide star rotation offsets unavailable
# GUIFWMED=             -9999.99 / Guide star FWHM unavailable
# GUIFW90 =             -9999.99 / Guide star FWHM unavailable
# GUIM1MED=             -9999.99 / Guide star zeropoints unavailable
# GUIM190 =             -9999.99 / Guide star zeropoints unavailable
# GUIXTNCT=             -9999.99 / Guide star extinction unavailable
# GUIZPRMS=             -9999.99 / Guide star zeropoint RMS unavailable
# M1M2MODV= 'NK.20140412'        / Telescope mirror position model version
# M1NOMX  =                   0. / [um] Modeled Primary mirror x position
# M1NOMY  =                1000. / [um] Modeled Primary mirror y position
# M1NOMZ  =                   0. / [um] Modeled Primary mirror z position
# M1NOMTIP=                 -19. / [arcsec] Modeled Primary mirror tip
# M1NOMTIL=                 -74. / [arcsec] Modeled Primary mirror tilt
# M2NOMX  =               460.63 / [um] Modeled Secondary mirror x position
# M2NOMY  =          -433.343754 / [um] Modeled Secondary mirror y position
# M2NOMZ  =         -1180.377665 / [um] Modeled Secondary mirror z position
# M2NOMTIP=            66.307374 / [arcsec] Modeled Secondary mirror tip
# M2NOMTIL=               197.19 / [arcsec] Modeled Secondary mirror tilt
# WVFA    =    -61.3246061005268 / [N] Wavefront A actuator force
# WVFB    =    -55.6299261134827 / [N] Wavefront B actuator force
# WVFC    =     -37.100191898503 / [N] Wavefront C actuator force
# WVFD    =    -37.2834586275026 / [N] Wavefront D actuator force
# WVFE    =    -48.8356902346568 / [N] Wavefront E actuator force
# WVFF    =    -55.6977837336499 / [N] Wavefront F actuator force
# WVFG    =    -38.2812169684796 / [N] Wavefront G actuator force
# WVFH    =     -29.464308014968 / [N] Wavefront H actuator force
# WVFI    =    -59.9874706942822 / [N] Wavefront I actuator force
# WVFJ    =     -63.863094949358 / [N] Wavefront J actuator force
# WVFK    =    -25.8873151155084 / [N] Wavefront K actuator force
# WVFL    =    -29.3557046851494 / [N] Wavefront L actuator force
# SEEING  =             -9999.99 / [arcsec]      Weather, seeing from DIMM, FWHM
# COMMENT WCS Coordinate Systems
# COMMENT ----------------------
# CUNIT1  = 'deg     '           / Units for focal plane coord system axis 1
# CUNIT2  = 'deg     '           / Units for focal plane coord system axis 1
# WCSNAMEA= 'RA/DEC  '           / Redundant reiteration of default WCS system
# CTYPE1A = 'RA---TAN'           / R.A. in tangent plane projection
# CUNIT1A = 'deg     '           / Units for focal plane coord system axis 1
# CRVAL1A =           209.539028 / R.A. at ref. pixel
# CRPIX1A =             -10547.8 / Ref. pixel of first axis
# CDELT1A =            7.121E-05 / R.A. pixel step
# CTYPE2A = 'DEC--TAN'           / Dec. in tangent plane projection
# CUNIT2A = 'deg     '           / Units for focal plane coord system axis 1
# CRVAL2A =            -7.239602 / Dec. at ref. pixel
# CRPIX2A =               -304.3 / Ref. pixel of second axis
# CDELT2A =            7.114E-05 / Dec. pixel step
# CD1_1A  =          -7.1918E-06 / CD transform matrix
# CD1_2A  =         -7.07753E-05 / CD transform matrix
# CD2_1A  =          7.08582E-05 / CD transform matrix
# CD2_2A  =          -7.1834E-06 / CD transform matrix
# WCSNAMEU= 'FP Position'        / Position on instrument focal plane
# CTYPE1U = 'linear  '           / Linear instrument focal plane position
# CUNIT1U = 'um      '           / Units for focal plane coord system axis 1
# CRVAL1U =                   0. / Focal plane position at reference pixel
# CRPIX1U =             -10547.8 / Ref. pixel of first axis
# CDELT1U =                  10. / Pixel step
# CTYPE2U = 'linear  '           / Linear instrument focal plane position
# CUNIT2U = 'um      '           / Units for focal plane coord system axis 2
# CRVAL2U =                   0. / Focal plane position at reference pixel
# CRPIX2U =               -304.3 / Ref. pixel of second axis
# CDELT2U =                  10. / Pixel step
# CD1_1U  =                 -10. / CD transform matrix
# CD1_2U  =                   0. / CD transform matrix
# CD2_1U  =                   0. / CD transform matrix
# CD2_2U  =                 -10. / CD transform matrix
# COMMENT Instrument Information
# COMMENT ----------------------
# PRESSURE=             0.000776 / [Torr] Micropirani pressure reading
# L3HUMID =                   9. / [%] Relative humidity in space above L3
# L3AIRTMP=                  9.6 / [C] Air temperature in space above L3
# L3DEWPT =                -21.8 / [C] Calculated dew point in space above L3
# ENHUMID =                  16. / [%] Rel. humidity of cam. environment (ferit)
# ENAIRTMP=                  7.9 / [C] Air temperature of camera environment
# ENDEWPT =                -16.4 / [C] Calculated dew point of camera environment
# GLYSTAT = 'supply  '           / Camera heat exchanger glycol status
# GLYMODE = 'auto    '           / Camera heat exchanger glycol mode
# FILTSTAT= 'STATIONARY'         / Filter mechanism status
# FILTER  = 'w       '           / Filter band name OPEN,u,g,r,i,z,y,w
# VIDMODE = '100x100@10'         / Video mode used (w pix x h pix x rate Hz)
# DEWTEM1 =                298.5 / [K] Dewar rtd 1 (CTI-Left head)
# DEWTEM2 =                163.7 / [K] Dewar rtd 2 (Copper plate)
# DEWTEM3 =                190.4 / [K] Dewar rtd 3 (OTA67 package)
# DEWTEM4 =                182.7 / [K] Dewar rtd 4 (Triangle post)
# DEWTEM5 =                  90. / [K] Dewar rtd 5 (Copper bar)
# DEWTEM6 =                 64.1 / [K] Dewar rtd 6 (CTI-Right head)
# SH_TEM  =                 32.4 / [K] Shack Hartmann head temperature
# SH_POS  =                    0 / [steps] Shack Hartmann arm position
# SH_STDLY=                 2000 / [2.04us/step] S-H arm step delay
# SH_ACCEL=                   10 / [2.04us/step^2] S-H acceleration param
# SH_MNDLY=                 4000 / [2.04us/step] S-H minimum step delay
# SH_ARMPN=                    2 / motion controller input pins
# SH_DIODE=                   7. / Vref/4096 (Vref=5V nominal) photodiode volts
# COMMENT Post-processing
# COMMENT ---------------
# BIASTOOL=                    F / [T=applied] Biastool applied to image data
# BIASTALG= 'Not available'      / Biastool not yet applied
# BIASTSWV= 'Not available'      / Biastool not yet applied
# BTOOLSWV= 'Not available'      / Burntool not yet applied
# BTOOLAR = 'Not available'      / Burntool not yet applied
# BTOOLFIT= 'Not available'      / Burntool not yet applied
# PSFFWMED=             -9999.99 / Burntool not yet applied
# PSFFW50 =             -9999.99 / Burntool not yet applied
# PSFM2MED=             -9999.99 / Burntool not yet applied
# PSFM250 =             -9999.99 / Burntool not yet applied
# PSFQ2MED=             -9999.99 / Burntool not yet applied
# PSFQ250 =             -9999.99 / Burntool not yet applied
# PSFT2MED=             -9999.99 / Burntool not yet applied
# PSFT250 =             -9999.99 / Burntool not yet applied
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# COMMENT  Reserved space.  This line can be used to add a new FITS card.
# HISTORY ppImage at 2014-04-24T08:55:34.163736
# HISTORY psLib version: tags/ipp-20130712/psLib@36171:36402
# HISTORY psLib source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# HISTORY psModules version: tags/ipp-20130712/psModules@36288
# HISTORY psModules source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# PHOT_V  = '36171   '
# HISTORY psphot version: tags/ipp-20130712/psphot@36171
# HISTORY psphot source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# HISTORY psastro version: tags/ipp-20130712/psastro@36637:36672
# HISTORY psastro source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# HISTORY ppStats version: tags/ipp-20130712/ppStats@36171
# HISTORY ppStats source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# IMAGE_V = '36171   '
# HISTORY ppImage version: tags/ipp-20130712/ppImage@36171
# HISTORY ppImage source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# HIERARCH DETREND.MASK = 'GPC1.MASK.20101215.XY13.fits' / Mask filename
# HIERARCH DETREND.NOISEMAP = 'GPC1.noisemap.norm.965.0.XY13.fits' / Noise Map fil
# HIERARCH DETREND.DARK = 'GPC1.DARKTEST.norm.858.0.XY13.fits' / Dark filename
# HIERARCH DETREND.FLAT = 'GPC1.FLATTEST.305.XY13.co.fits' / Flat filename
# HIERARCH DETREND.NONLIN = 'linearity_data.XY13.fits' / Non-linearity table filen
# HIERARCH DETREND.VIDEODARK = 'GPC1.VIDEODARK.981.0.XY13.fits' / VideoDark filena
# PTRN_ROW=                    T / PATTERN.ROW correction applied
# PTRN_CON=                    T / PATTERN.CONTINUITY correction applied
# NAXIS1  =                 4846 / Size in x
# NAXIS2  =                 4868 / Size in y
# PSMOSAIC= 'CHIP    '           / Mosaicked level
# CD1_1   =          -7.1918E-06
# CD1_2   =          7.07753E-05
# CD2_1   =          7.08582E-05
# CD2_2   =           7.1834E-06
# CDETTEM =                 -87. / Temperature of chip
# CELLMODE=                    F / Does this OTA have any video cells
# CMMTOBS = '176.OSS.R13S1.Q.w ps1_14_3759 visit 1' / Observation comment
# OBS_MODE= 'OSS     '           / Observation mode (eg, survey id)
# AIRMASS =                1.274 / Airmass at boresight
# FILTERID= 'w.00000 '           / Filter used (instrument name)
# POSANGLE=             275.7954 / Position angle of instrument
# ROT     =            -137.7034 / Rotator angle of instrument
# RA      =           209.539028 / Right Ascension of boresight
# DEC     =            -7.239602 / Declination of boresight
# OBSTYPE = 'OBJECT  '           / Type of observation
# OBJECT  = 'ps1_14_3759'        / Object of observation
# ALT     =            51.166152 / Altitude of boresight
# AZ      =           134.802918 / Azimuth of boresight
# DETTEM  =                -79.6 / Temperature of focal plane
# M1X     =                   0. / Primary Mirror X Position
# M1Y     =                1000. / Primary Mirror Y Position
# M1Z     =            -0.008933 / Primary Mirror Z Position
# M1TIP   =            -19.00254 / Primary Mirror TIP
# M1TILT  =            -74.00186 / Primary Mirror TILT
# M2X     =              460.579 / Primary Mirror X Position
# M2Y     =            -433.1891 / Primary Mirror Y Position
# M2Z     =             -1179.55 / Primary Mirror Z Position
# M2TIP   =              66.2591 / Primary Mirror TIP
# M2TILT  =             197.1644 / Primary Mirror TILT
# ENVTEM  =                  6.8 / Environment: Temperature
# ENVHUM  =                  19. / Environment: Humidity
# ENVWIN  =                  12. / Environment: Wind speed
# ENVDIR  =                  61. / Environment: Wind direction
# TELTEMM1=                  8.4 / Telescope Temperatures: M1
# TELTEMMS=                  8.2 / Telescope Temperatures: M1 cell
# TELTEMM2=                 5.85 / Telescope Temperatures: M2
# TELTEMSP=                 5.45 / Telescope Temperatures: spider
# TELTEMTR=                 6.25 / Telescope Temperatures: truss
# TELTEMEX=                  5.7 / Telescope Temperatures: extra
# PONTIME =             6094727. / Power On Time
# BTOOLAPP=                    F / [T=applied] Burn streaks applied to image data
# EXPREQ  =                  45. / Exposure time (sec)
# MAXLIN  =               54500. / Saturation level (counts)
# SHUTOUTC= '2014-04-24T08:28:28.270418' / Time of exposure
# IMAGEID =             58331266 / Image identifier
# SOURCEID=                   33 / Source identifier
# PHOTCODE= 'GPC1.w.XY13'        / photcode from FPA concepts
# APMIFIT =           0.09696646 / aperture residual
# DAPMIFIT=           0.03163467 / ap residual scatter
# NAPMIFIT=                  185 / number of apresid stars
# NPSFSTAR=                  225 / Number of stars used to make PSF
# APLOSS  =          -0.07231522 / aperture loss (mag)
# APREFOFF=          -0.03125572 / offset to ref aperture
# FWHM_MAJ=             8.397646 / PSF FWHM Major axis (mean)
# FW_MJ_SG=                   0. / PSF FWHM Major axis (sigma)
# FW_MJ_LQ=             8.397651 / PSF FWHM Major axis (lower quartile)
# FW_MJ_UQ=             8.397651 / PSF FWHM Major axis (upper quartile)
# FWHM_MIN=             8.007746 / PSF FWHM Minor axis (mean)
# FW_MN_SG=                   0. / PSF FWHM Minor axis (sigma)
# FW_MN_LQ=             8.007741 / PSF FWHM Minor axis (lower quartile)
# FW_MN_UQ=             8.007741 / PSF FWHM Minor axis (upper quartile)
# ANGLE   =            0.7171677 / PSF angle
# PSFMODEL= 'PS_MODEL_PS1_V1'    / PSF Model Name
# PSF_OK  =                    T / Valid PSF Model?
# IQ_NSTAR=                  473 / Number of stars used for IQ measurements
# IQ_FW1  =             7.028607 / FWHM of Major Axis from moments
# IQ_FW1_E=             0.322421 / FWHM scatter (Major) from moments
# IQ_FW2  =             6.753764 / FWHM of Minor Axis from moments
# IQ_FW2_E=            0.2821542 / FWHM scatter (Minor) from moments
# IQ_M2   =            0.6873921 / M_2 = sqrt (M_c2^2 + M_s2^2)
# IQ_M2_ER=            0.6501997 / Stdev of M_2
# IQ_M2_LQ=            0.2534935 / Lower Quartile of M_2
# IQ_M2_UQ=            0.8673103 / Upper Quartile of M_2
# IQ_M2C  =           0.06335701 / M_2c = sum f r^2 cos(2phi) / sum f
# IQ_M2C_E=            0.7011778 / Stdev of M_2c
# IQ_M2C_L=           -0.2060585 / Lower Quartile of M_2c
# IQ_M2C_U=            0.2574844 / Upper Quartile of M_2c
# IQ_M2S  =            0.2117668 / M_2s = sum f r^2 cos(2phi) / sum f
# IQ_M2S_E=            0.5963686 / Stdev of M_2s
# IQ_M2S_L=         -0.002026242 / Lower Quartile of M_2s
# IQ_M2S_U=             0.390616 / Upper Quartile of M_2s
# IQ_M3   =            0.4880132 / M_3 = sqrt (M_c3^2 + M_s3^2)
# IQ_M3_ER=            0.4925527 / Stdev of M_3
# IQ_M3_LQ=            0.1220745 / Lower Quartile of M_3
# IQ_M3_UQ=            0.6967095 / Upper Quartile of M_3
# IQ_M4   =           0.07954576 / M_4 = sqrt (M_c4^2 + M_s4^2)
# IQ_M4_ER=           0.07500372 / Stdev of M_4
# IQ_M4_LQ=           0.02654924 / Lower Quartile of M_4
# IQ_M4_UQ=              0.11196 / Upper Quartile of M_4
# FSATUR  =                   0. / SATURATION MAG
# FLIMIT  =                   0. / COMPLETENESS MAG
# HIERARCH PSPHOT.PSF.APRESID = -0.1910674 / locus of PSF stars in PSF_MAG - KRON_
# HIERARCH PSPHOT.PSF.APRESID.SYSERR = 0.02370453 / systematic error of PSF_MAG -
# HIERARCH PSPHOT.CR.MAX.SIZE = 0.8 / dynamically-set minor axis size limit for co
# HIERARCH PSPHOT.CR.MAX.MAG = -8. / dynamically-set kron magnitude limit for cosm
# HIERARCH EFFECTIVE_AREA = 304.9563 / Effective Area
# HIERARCH SIGNIFICANCE_SCALE_FACTOR = 135.1664 / Signicance scale factor
# MSKY_MN =             340.4741 / sky model mean
# MSKY_SIG=             1.901099 / sky model stdev
# MSKY_MIN=             336.0406 / sky model minimum value
# MSKY_MAX=             344.6613 / sky model maximum value
# MSKY_NX =                   13 / sky model size (x)
# MSKY_NY =                   13 / sky model size (y)
# MSKY_DEV=             19.00664 / sky stdev
# MSKY_DQ =            0.3513184 / sky quartile slope
# HIERARCH DETEFF.MAGREF = -8.127983 / Magnitude reference
# DT_PHOT =             25.27226 / elapsed psphot time
# NSTARS  =                 4700 / Number of sources
# NDET    =                 2361 / Number of detections
# NDET_EXT=                  325 / Number of extended sources
# NDET_CR =                   25 / Number of cosmic rays
# NDET_FRC=                    0 / Number of Forced detections
# HISTORY psastro at 2014-04-24T09:12:11.212470
# PSLIB_V = '36171:36402'
# HISTORY psLib version: tags/ipp-20130712/psLib@36171:36402
# HISTORY psLib source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# MODULE_V= '36288   '
# HISTORY psModules version: tags/ipp-20130712/psModules@36288
# HISTORY psModules source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# STATS_V = '36171   '
# HISTORY ppStats version: tags/ipp-20130712/ppStats@36171
# HISTORY ppStats source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# ASTRO_V = '36637:36672'
# HISTORY psastro version: tags/ipp-20130712/psastro@36637:36672
# HISTORY psastro source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# PSREFCAT= 'PS1.REF.20120524'
# DETECTOR= 'CCID58-3-06a1'      / Chip identifier
# GAIN    =             1.013516 / CCD gain (e/count)
# RDNOISE =             5.143421 / CCD read noise (e)
# SATLEVEL=               54500. / Saturation level (counts)
# LOWLEVEL=                   0. / Bad level (counts)
# EXPTIME =                  45. / Exposure time (sec)
# DARKTIME=             52.74424 / Time since flush (sec)
# CCDSUM  = '1 1     '           / Binning in x
# MJD-OBS =     56771.3535100743 / Time of exposure
# TRIMSEC = '[nan:nan,nan:nan]'  / Trim section
# BIASSEC = ''
# EXTDATA = 'XY13.psf'           / name of table extension
# EXTTYPE = 'IMAGE   '           / extension type
# AST_CDX =            0.1506523 / chip astrometry X stdev (arcsec)
# AST_CSX =            0.1521459 / chip astrometry X systematic err (arcsec)
# AST_CRX =            0.4193498 / chip astrometry X 10-90 percentile (arcsec)
# AST_CDY =            0.1148573 / chip astrometry Y stdev (arcsec)
# AST_CSY =            0.1175715 / chip astrometry Y systematic err (arcsec)
# AST_CRY =            0.2982426 / chip astrometry Y 10-90 percentile (arcsec)
# DT_ASTR =             14.46812 / elapsed psastro time
# PERROR  =            0.2045867 / astrometry error (pixels)
# CERROR  =           0.05222852 / astrometry error (arcsec)
# CPRECISE=          0.003329969 / astrometry precision (arcsec)
# NASTRO  =                  246 / number of astrometry stars
# EQUINOX =                2000.
# AST_MDX =           0.05186417 / mosaic astrometry X stdev (arcsec)
# AST_MSX =           0.04623488 / mosaic astrometry X systematic err (arcsec)
# AST_MRX =            0.1345102 / mosaic astrometry X 10-90 percentile (arcsec)
# AST_MDY =           0.05259287 / mosaic astrometry Y stdev (arcsec)
# AST_MSY =           0.04717782 / mosaic astrometry Y systematic err (arcsec)
# AST_MRY =            0.1340355 / mosaic astrometry Y 10-90 percentile (arcsec)
# CTYPE1  = 'RA---WRP'
# CTYPE2  = 'DEC--WRP'
# CRVAL1  =                   0.
# CRVAL2  =                   0.
# CRPIX1  =    -9911.27666435504
# CRPIX2  =    -207.451454147691
# CDELT1  =     1.02276614402446
# CDELT2  =     1.01005877411762
# PC001001=    0.999997824360318
# PC001002=  0.00211221413774539
# PC002001=  -0.0116738230186925
# PC002002=     0.99993013321142
# PCA1X0Y2=   1.836760747175E-07
# PCA2X0Y2= -2.97921344642221E-07
# PCA1X0Y3= 5.98406376118314E-13
# PCA2X0Y3= 2.98267140576793E-11
# PCA1X1Y1= -1.69893543643558E-07
# PCA2X1Y1= 1.03244428401251E-08
# PCA1X1Y2= -1.68096430545877E-11
# PCA2X1Y2= 1.57053640396753E-12
# PCA1X2Y0= -1.08023424632808E-06
# PCA2X2Y0= 7.68557210490513E-07
# PCA1X2Y1= 1.02287334817718E-11
# PCA2X2Y1= -1.39749203099083E-12
# PCA1X3Y0= 2.79324317850862E-11
# PCA2X3Y0= -1.9938108729434E-11
# NPLYTERM=                    3
# ZPT_OBS =             25.89705 / measured zero point
# ZPT_REF =                 26.3 / reference zero point
# ZPT_ERR =             0.048666 / error on zero point
# ZPT_OFF =            0.4029503 / zero point offset
# PSFORMAT= 'MEF     '
# IMNAXIS1=                 4846 / Number of columns in original image
# IMNAXIS2=                 4868 / Number of rows in original image
# EXTNAME = 'XY13.hdr'

# %% [markdown]
# Each image from each detector from each exposure gets a unique, sequential ID number.  This is very useful for creating unique IDs, if needed.

# %%
[(hdu.name, hdu.header['IMAGEID']) for hdu in hdus if '.hdr' in hdu.name][0:10]
# Out:
# [('XY01.hdr', 58331257),
#  ('XY02.hdr', 58331258),
#  ('XY03.hdr', 58331259),
#  ('XY04.hdr', 58331260),
#  ('XY05.hdr', 58331261),
#  ('XY06.hdr', 58331262),
#  ('XY10.hdr', 58331263),
#  ('XY11.hdr', 58331264),
#  ('XY12.hdr', 58331265),
#  ('XY13.hdr', 58331266)]

# %% [markdown]
# The sources detected by each individual chip are stored in the '.psf' extensions, one row for each.  There are many, many columns (i.e. 'features') for each detection.  Of interest are the local chip coordinates ('X_PSF', 'Y_PSF'), the magnitude or brightness of the source ('CAL_PSF_MAG'), a bit mask of flags ('FLAGS'), and the moments or shape parameters.
#
# We will describe the 'FLAGS' field in detail later.

# %%
hdus['XY13.psf'].columns
# Out:
# ColDefs(
#     name = 'IPP_IDET'; format = '1J'; bscale = 1; bzero = 2147483648
#     name = 'X_PSF'; format = '1E'
#     name = 'Y_PSF'; format = '1E'
#     name = 'X_PSF_SIG'; format = '1E'
#     name = 'Y_PSF_SIG'; format = '1E'
#     name = 'POSANGLE'; format = '1E'
#     name = 'PLTSCALE'; format = '1E'
#     name = 'PSF_INST_MAG'; format = '1E'
#     name = 'PSF_INST_MAG_SIG'; format = '1E'
#     name = 'PSF_INST_FLUX'; format = '1E'
#     name = 'PSF_INST_FLUX_SIG'; format = '1E'
#     name = 'AP_MAG'; format = '1E'
#     name = 'AP_MAG_RAW'; format = '1E'
#     name = 'AP_MAG_RADIUS'; format = '1E'
#     name = 'CAL_PSF_MAG'; format = '1E'
#     name = 'CAL_PSF_MAG_SIG'; format = '1E'
#     name = 'RA_PSF'; format = '1D'
#     name = 'DEC_PSF'; format = '1D'
#     name = 'PEAK_FLUX_AS_MAG'; format = '1E'
#     name = 'SKY'; format = '1E'
#     name = 'SKY_SIGMA'; format = '1E'
#     name = 'PSF_CHISQ'; format = '1E'
#     name = 'CR_NSIGMA'; format = '1E'
#     name = 'EXT_NSIGMA'; format = '1E'
#     name = 'PSF_MAJOR'; format = '1E'
#     name = 'PSF_MINOR'; format = '1E'
#     name = 'PSF_THETA'; format = '1E'
#     name = 'PSF_QF'; format = '1E'
#     name = 'PSF_QF_PERFECT'; format = '1E'
#     name = 'PSF_NDOF'; format = '1J'
#     name = 'PSF_NPIX'; format = '1J'
#     name = 'MOMENTS_XX'; format = '1E'
#     name = 'MOMENTS_XY'; format = '1E'
#     name = 'MOMENTS_YY'; format = '1E'
#     name = 'MOMENTS_M3C'; format = '1E'
#     name = 'MOMENTS_M3S'; format = '1E'
#     name = 'MOMENTS_M4C'; format = '1E'
#     name = 'MOMENTS_M4S'; format = '1E'
#     name = 'MOMENTS_R1'; format = '1E'
#     name = 'MOMENTS_RH'; format = '1E'
#     name = 'KRON_FLUX'; format = '1E'
#     name = 'KRON_FLUX_ERR'; format = '1E'
#     name = 'KRON_FLUX_INNER'; format = '1E'
#     name = 'KRON_FLUX_OUTER'; format = '1E'
#     name = 'FLAGS'; format = '1J'; bscale = 1; bzero = 2147483648
#     name = 'FLAGS2'; format = '1J'; bscale = 1; bzero = 2147483648
#     name = 'PADDING2'; format = '1J'
#     name = 'N_FRAMES'; format = '1I'; bscale = 1; bzero = 32768
#     name = 'PADDING'; format = '1I'
# )

# %% [markdown]
# Here is a single row corresponding to a single detection.
# Each data element corresponds to the columns above.

# %%
det_num = 500 
hdus['XY13.psf'].data[det_num]
# Out:
# (500, 532.34521, 3001.2729, 0.082795978, 0.082795978, -95.903122, -0.25662765, -9.7277431, 0.038914107, 7782.1094, 302.83383, -10.020698, -9.9894419, 20.0, 20.302338, 0.048666, 209.68822421212249, -8.0081576034947144, -5.0362172, 338.45142, 18.572845, 4261.1543, nan, 6.0369453, 3.1184096, 3.0432136, 37.321762, 0.99916071, 0.99916071, 3837, 3838, 10.945186, -0.77285713, 11.553526, -0.28258851, 0.038668931, 0.15275675, 0.030656829, 6.2242961, 1.9925134, 9356.3408, 517.90814, 4599.666, nan, 35667969, 128, 0, 0, 0)

# %% [markdown]
# We can grab all the data in a column like so.  These are numpy arrays that can be manipulated as such.

# %%
hdus['XY13.psf'].data['RA_PSF'], hdus['XY13.psf'].data['DEC_PSF']
# Out:
# (array([ 209.8100486 ,  209.77830744,  209.62594988, ...,  209.57681909,
#          209.61745459,  209.59006807]),
#  array([-8.09592031, -8.09560228, -8.02575972, ..., -8.07404797,
#         -7.99218592, -8.12218768]))

# %% [markdown]
# We now repeat the  plot made above of the detections on a given chip

# %%
plt.scatter(hdus['XY13.psf'].data['RA_PSF'], hdus['XY13.psf'].data['DEC_PSF'], s=3)

# %% [markdown]
# ### Matched Reference Stars
#
# The IPP provides a table of all the reference stars used for fitting the astrometric and photometric solution for the exposure.  Again, this is incredibly useful!

# %%
mrefs = hdus['MATCHED_REFS']

zpt_obs = hdus['XY01.hdr'].header['ZPT_OBS']
exptime = hdus['XY01.hdr'].header['EXPTIME']

mag_obs = mrefs.data['MAG_INST'] + zpt_obs + 2.5*np.log10(exptime)
mag_ref = mrefs.data['MAG_REF']

# %%
mrefs.columns
# Out:
# ColDefs(
#     name = 'RA'; format = '1D'
#     name = 'DEC'; format = '1D'
#     name = 'X_CHIP'; format = '1E'
#     name = 'Y_CHIP'; format = '1E'
#     name = 'X_CHIP_FIT'; format = '1E'
#     name = 'Y_CHIP_FIT'; format = '1E'
#     name = 'X_FPA'; format = '1E'
#     name = 'Y_FPA'; format = '1E'
#     name = 'MAG_INST'; format = '1E'
#     name = 'MAG_REF'; format = '1E'
#     name = 'COLOR_REF'; format = '1E'
#     name = 'CHIP_ID'; format = '4A'
# )

# %%
mean_diff = (mag_obs-mag_ref).mean()

# %%
mrefs.columns
# Out:
# ColDefs(
#     name = 'RA'; format = '1D'
#     name = 'DEC'; format = '1D'
#     name = 'X_CHIP'; format = '1E'
#     name = 'Y_CHIP'; format = '1E'
#     name = 'X_CHIP_FIT'; format = '1E'
#     name = 'Y_CHIP_FIT'; format = '1E'
#     name = 'X_FPA'; format = '1E'
#     name = 'Y_FPA'; format = '1E'
#     name = 'MAG_INST'; format = '1E'
#     name = 'MAG_REF'; format = '1E'
#     name = 'COLOR_REF'; format = '1E'
#     name = 'CHIP_ID'; format = '4A'
# )

# %%
mrefs.data['MAG_REF']
# Out:
# array([ 15.13035965,  15.13486671,  15.16680336, ...,  19.56411362,
#         19.61084938,  19.61094284], dtype=float32)

# %%
plt.scatter(mag_ref, mag_obs, s=1)

# %%
blah= plt.hist(mag_obs-mag_ref, bins=1000)
plt.vlines(mean_diff, -10, 4000)
plt.xlim(-0.2, 0.2)
# Out:
# (-0.2, 0.2)

# %% [markdown]
# DETEFF.MAGREF refers to an instrumental magnitude.  To use that, we take the simulated apparent magnitude, subtract the zero point and 2.5*log(exptime) to get an instrumental magnitude.
#
# We then compare the instrumental magnitude to the detection efficiency curve.

# %% [markdown]
# The astrometry in 'MATCHED_REFS' is also very good.  Here are histograms of the residuals of the fitted x, y pixel positions.

# %%
mrefs.columns
# Out:
# ColDefs(
#     name = 'RA'; format = '1D'
#     name = 'DEC'; format = '1D'
#     name = 'X_CHIP'; format = '1E'
#     name = 'Y_CHIP'; format = '1E'
#     name = 'X_CHIP_FIT'; format = '1E'
#     name = 'Y_CHIP_FIT'; format = '1E'
#     name = 'X_FPA'; format = '1E'
#     name = 'Y_FPA'; format = '1E'
#     name = 'MAG_INST'; format = '1E'
#     name = 'MAG_REF'; format = '1E'
#     name = 'COLOR_REF'; format = '1E'
#     name = 'CHIP_ID'; format = '4A'
# )

# %%
mrefs.data['X_CHIP']
# Out:
# array([ 1718.19506836,  2375.35424805,   968.7701416 , ...,   144.92158508,
#         3816.65820312,  2312.65820312], dtype=float32)

# %%
mrefs.data['X_CHIP_FIT']
# Out:
# array([ 1718.16906738,  2375.46362305,   968.65368652, ...,    19.8550663 ,
#         1028.28649902,   983.02874756], dtype=float32)

# %%
blah = plt.hist(mrefs.data['X_CHIP']-mrefs.data['X_CHIP_FIT'], range=(-1, 1), bins=100)
blah = plt.hist(mrefs.data['Y_CHIP']-mrefs.data['Y_CHIP_FIT'], range=(-1, 1), bins=100)
#plt.xlim(-1, 1)

# %% [markdown]
# ### False Detections and Bayesian Stuff
#
# The number of detections from a particular chip, or even cell, should be a function of the number of live pixels in it.  Dead pixels don't report photons.  Amazingly, there might be 10^12 detections so far in the Pan-STARRS survey.  That estimate comes the product of 1.3x10^6 exposures and 1.5x10^5 detections/exposure.  The camera has 1.4x10^9 pixels.  That means that on average each pixel has been at the center of about 700 detections, some real and some false.
# }
# If we make the assumption that detections that correspond to sources in the stationary catalog are real and that all other detections are false, which is not a bad assumption, we can estimate a prior probability that a detection is real or false.
#
# $$  P(A|B) = \frac{P(B|A) P(A)}{P(B)}  $$
#
#
#
# Some pixels will contribute much more than the average number of detections.  But the number and distribution of real sources, other than moving solar system objects, is not changing.  Those locations are essentially fixed.    So we can keep track of which detector, cell, and pixel locattion each detection is centered on.
#
# Our real-bogus classifier will use all the information in the smf, both from the chip and row in which the detection is reported and the other information in the smf, as well as the prior information that comes from the accumulation of many exposures, to estimate the probability that a particular detection is real or bogus.
#
# The clasifier could use information about sky brightness, time of day, stellar crowding in the region, etc, in its estimates.
#
#
# - true positive: a detection corresponding to a real source is reported at a given pixel location, and it is classified as real.
# - true negative: a detection for which there is no physical source is reported at a given pixel location, and it is classified as false.
# - false positive: a detection for which there is no physical source is reported at a given pixel location, and it is classified as real.
# - false negative: a detection corresponding to a real source is reported at a given pixel location, and it is classified as false.
#
# We can estimate some of these probabilities because we have an extensive catalog of known sources.  In many cases we will know of a source that is predicted to be seen at a given pixel location.  We will have a prior estimate of its magnitude in various filters, which we can use to estimate the likelihood of detecting it.  Because there are so many exposures, most astrophysical objects that can be detected by Pan-STARRS will have been detected at some point.  Of course, there are some variable sources that might be only rarely detected and there are moving objects, the focus of this project, but these are a small fraction of the total.  We can use the known stationary and moving sources to estimate the true positive rate and false negative rate.
#
# We also have an abundance of false detections.  Some occur in particular detector regions.  Some are due to sky fluctations or scatter light.  Regardless, if a detection does not correspond to an object in the catalog, most likely it is false.  There are some detector regions with many more false detections.  Detections in those regions are more likely to be false.   We can use this information to estimate the true negative and false positve rates.
#
# A few versions of the IPP software have been used; the version used is noted in the smf headers. The static masks are updated from time to time.  And the telescope, camera, and detectors have gone through various changes.  All of these can affect the detection efficiencies and false positive rates.  Fortunately, there is enough data to track these changes and their effects.
#
# Let's start by exploring the data.
#
# We can extract all the chip-level x,y positions for all the detectors into a couple of lists, for plotting.

# %%
# Need to defend against missing extensions.
x, y = [],[]
for chip in chips:
    x += list(hdus[chip+'.psf'].data['X_PSF'])
    y += list(hdus[chip+'.psf'].data['Y_PSF'])

# %% [markdown]
# If we <strong> fold </strong> the x,y values on the scales of the separations of cells (and hence "stack" the detections from all cells), we see the edges have an abundance of detections. (A plot is shown below, with horizontal and vertical lines to guide the eye.)
#
# Most of the excess detections along the edges of the cells must be false; nature isn't playing astrophysical tricks on us.

# %%
plt.scatter(ps1_utils.foldx(x), ps1_utils.foldy(y), s=0.1)
plt.xlim(-5,595)
plt.ylim(-5,603)
plt.hlines((10, 585), 0,600)
plt.vlines((12, 580), 0,600)

# %% [markdown]
# The fraction of pixels on the edge of a cell is a few percent, but the number of false detections there is very high.

# %%
(17*590 + 21*598)/(590*598)
# Out:
# 0.064021313984468

# %% [markdown]
# We can extract various sets of detections to get a sense of how many false detections there are in the edges.
#  - Here we are aggressively triming all detections along the edges

# %%
middle_xs = [x for x,y in zip(x, y) if ps1_utils.foldy(y)>10 and ps1_utils.foldy(y)<585]
middle_ys = [y for x,y in zip(x, y) if ps1_utils.foldx(x)>12 and ps1_utils.foldy(x)<580]

middle_xys = [(x,y) for (x,y) in zip(x, y) if ps1_utils.foldx(x)>13 and ps1_utils.foldx(x)<580 and ps1_utils.foldy(y)>6 and ps1_utils.foldy(y)<587]
middle_xys = np.array(middle_xys)

# %% [markdown]
# The fraction of the detections that are in the center region is about 86%.  I'll try to estimate the false detection rate in the edge region and in the center in a bit.  We can assume that the rate of real detections is intrinsically similar.  Or rather, the number of real objects that are sending photons in the regions is the same per pixel.

# %%
len(middle_xys)/len(x)
# Out:
# 0.7359786168730942

# %%
plt.scatter(ps1_utils.foldx(middle_xys[:,0]), ps1_utils.foldy(middle_xys[:,1]), s=0.1)

# %% [markdown]
# #### In the cells below we make one-dimensional (x & then y) plots of the number of detections to give approximate justification for the choice of edge-trimming width used above

# %%
foo = plt.hist(ps1_utils.foldx(middle_xs), bins=600)
plt.vlines((12, 580), 0,600)
plt.ylim(-10,3000)
# Out:
# (-10, 3000)

# %%
foo = plt.hist(ps1_utils.foldy(middle_ys), bins=600)
plt.vlines((10, 585), 0,2000)
plt.ylim(-10,5000)
# Out:
# (-10, 5000)
